# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
path = 'C:\\Users\\CodeLab\\Videos\\path\\'
os.chdir(path)

# %%
data = pd.read_csv('Ecommerce.csv')

# %%
data
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0       835 Frank Tunnel\r\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\r\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\r\nCobbborough,...            Bisque
# 3    1414 David Throughway\r\nPort Jason, OH 22070-...       SaddleBrown
# 4    14023 Rodriguez Passage\r\nPort Jacobville, PR...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %%
data.columns
# Out:
# Index(['Email', 'Address', 'Avatar', 'Avg. Session Length', 'Time on App',
#        'Time on Website', 'Length of Membership', 'Yearly Amount Spent'],
#       dtype='object')

# %%
import seaborn as sns
sns.set()

# %%
plt.figure(figsize=(12,8))
sns.jointplot(data = data, x = 'Time on Website', y = 'Yearly Amount Spent')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.jointplot(data = data, x = 'Time on App', y = 'Yearly Amount Spent')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.jointplot(data = data, x = 'Time on App', y = 'Length of Membership', kind='hex')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.pairplot(data)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.jointplot(data = data, x = 'Length of Membership', y = 'Yearly Amount Spent', kind='reg')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.lmplot(data = data, x = 'Length of Membership', y = 'Yearly Amount Spent',)
plt.show()

# %%
data.columns
# Out:
# Index(['Email', 'Address', 'Avatar', 'Avg. Session Length', 'Time on App',
#        'Time on Website', 'Length of Membership', 'Yearly Amount Spent'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

# %%
X = data[['Avg. Session Length', 'Time on App',
       'Time on Website', 'Length of Membership',]]
y = data['Yearly Amount Spent']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state = 101)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.coef_
# Out:
# array([26.02948861, 38.70983485,  0.35618404, 61.47280903])

# %%
model.intercept_
# Out:
# -1057.6995744132498

# %%
predict = model.predict(X_test)
predict
# Out:
# array([456.61303865, 402.86759325, 409.28303802, 591.87744119,
#        590.45805085, 549.10328198, 577.73384983, 716.29274839,
#        473.55196468, 546.27189564, 337.47672426, 500.45263167,
#        553.46927122, 409.22125099, 766.41897076, 545.97637593,
#        693.77658658, 507.49943222, 573.37979139, 573.54521438,
#        397.39798193, 555.16201736, 458.35507403, 482.70625714,
#        559.39495907, 412.85811054, 532.44048262, 377.57887943,
#        535.15243506, 448.1195441 , 595.96723677, 667.74018422,
#        512.04948273, 573.31053385, 505.25234611, 565.79901328,
#        460.10382733, 449.57153219, 422.58816837, 456.63420235,
#        598.25072639, 449.97454297, 616.00787846, 511.86572049,
#        504.33762368, 515.93194394, 568.51808328, 551.99040739,
#        356.00451872, 464.81658973, 481.68495717, 534.42876633,
#        255.4664104 , 505.42655585, 520.26978457, 314.39963628,
#        502.43586487, 387.00034009, 473.20092986, 432.5830045 ,
# ...

# %%
plt.scatter(y_test, predict)
plt.show()

# %%
from sklearn import metrics

# %%
print('MAE: ', metrics.mean_absolute_error(y_test, predict))
print('MSE: ', metrics.mean_squared_error(y_test, predict))
print('RMSE: ', np.sqrt(metrics.mean_absolute_error(y_test, predict)))
# Out:
# MAE:  7.7589075404578445
# MSE:  91.82335857016871
# RMSE:  2.7854815634747694

# %%
plt.figure(figsize=(12,8))
sns.distplot(data['Yearly Amount Spent'], bins=70)
plt.show()
